# %%
import pandas as pd

# %%
df = pd.read_csv("/home/jvcl/Downloads/streamlit-pandasai-main/data/Mozilla.csv", delimiter=';')
df
# Out:
#         bugID                         ct  \
# 0     1600000  2019-11-28 01:50:26 -0800
# 1     1600002  2019-11-28 02:00:31 -0800
# 2     1600003  2019-11-28 02:06:25 -0800
# 3     1600004  2019-11-28 02:06:49 -0800
# 4     1600005  2019-11-28 02:13:28 -0800
# ...       ...                        ...
# 4160  1604996  2019-12-18 18:58:06 -0800
# 4161  1604997  2019-12-18 19:43:27 -0800
# 4162  1604998  2019-12-18 19:44:08 -0800
# 4163  1604999  2019-12-18 19:44:29 -0800
# 4164  1605000  2019-12-18 19:49:52 -0800
#
#                                                      sd  \
# 0     Simplify functions to select a search engine l...
# 1     [wpt-sync] Sync PR 20497 - Add tests for conte...
# 2     2.45% displaylist_mutate (linux64-shippable) r...
# 3     Replace current push from alert summaries with...
# 4     Assertions for "test mode" print an outdated m...
# ...                                                 ...
# 4160  C-C TB |make mozmill| test-image-insertion-dia...
# ...
